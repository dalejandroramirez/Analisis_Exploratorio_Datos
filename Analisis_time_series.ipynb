# %% [markdown]
# Pagina donde está la serie de tiempo https://data.nasdaq.com/tools/python

# %%
import quandl

QUANDL_API_KEY="jGtG6sRFnKhCvZu6rrmS"

quandl.ApiConfig.api_key=QUANDL_API_KEY

# %%
quandl.get("FRED/GDP")
# Out:
#                 Value
# Date
# 1947-01-01    243.164
# 1947-04-01    245.968
# 1947-07-01    249.585
# 1947-10-01    259.745
# 1948-01-01    265.742
# ...               ...
# 2020-07-01  21138.574
# 2020-10-01  21477.597
# 2021-01-01  22038.226
# 2021-04-01  22740.959
# 2021-07-01  23202.344
#
# [299 rows x 1 columns]

# %% [markdown]
# df_real.resample("MS").ffill().dropna()
#
# "MS" quiere decir por mes

# %%
df_real=quandl.get("CHRIS/CME_GC1",column_index=6,collapse="weekly",start_date="2010-01-01")

df_real.resample("MS").ffill().dropna()
# Out:
#             Settle
# Date
# 2010-02-01  1083.0
# 2010-03-01  1118.9
# 2010-04-01  1104.3
# 2010-05-01  1153.1
# 2010-06-01  1212.2
# ...            ...
# 2021-03-01  1731.6
# 2021-04-01  1734.7
# 2021-05-01  1777.8
# 2021-06-01  1902.5
# 2021-07-01  1776.6
#
# [138 rows x 1 columns]

# %%
ventana_t=df_real.rolling(10)
media_df_real=ventana_t.mean()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,8))
plt.plot(df_real,label="original")
plt.plot(media_df_real,label="Media")
plt.legend()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
season_variable=seasonal_decompose(df_real,period=12)

# %%
season_variable.plot()
